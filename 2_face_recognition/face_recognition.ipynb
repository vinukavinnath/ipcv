# %% [markdown]
# # Face Recognition with Intelligent Template Matching

# %%
conda install opencv
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - opencv
#
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   eigen              pkgs/main/win-64::eigen-3.4.0-h59b6b97_0
#   ffmpeg             pkgs/main/win-64::ffmpeg-4.2.2-he774522_0
#   freetype           pkgs/main/win-64::freetype-2.12.1-ha860e81_0
#   giflib             pkgs/main/win-64::giflib-5.2.1-h8cc25b3_3
#   glib               pkgs/main/win-64::glib-2.78.4-hd77b12b_0
#   glib-tools         pkgs/main/win-64::glib-tools-2.78.4-hd77b12b_0
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0
#   hdf5               pkgs/main/win-64::hdf5-1.12.1-h51c971a_3
#   icc_rt             pkgs/main/win-64::icc_rt-2022.1.0-h6049295_2
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46320
#   jpeg               pkgs/main/win-64::jpeg-9e-h2bbff1b_1
#   krb5               pkgs/main/win-64::krb5-1.20.1-h5b6d351_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libclang           pkgs/main/win-64::libclang-14.0.6-default_hb5a9fac_1
#   libclang13         pkgs/main/win-64::libclang13-14.0.6-default_h8e68704_1
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_1
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_1
#   libglib            pkgs/main/win-64::libglib-2.78.4-ha17d25a_0
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_3
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0
#   libpq              pkgs/main/win-64::libpq-12.17-h906ac69_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.3-h23ce68f_0
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-hd77b12b_0
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0
#   libwebp            pkgs/main/win-64::libwebp-1.3.2-hbc33d0d_0
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.3.2-h2bbff1b_0
#   libxml2            pkgs/main/win-64::libxml2-2.10.4-h0ad7f3c_2
#   libxslt            pkgs/main/win-64::libxslt-1.1.37-h2bbff1b_1
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h6b88ed4_46358
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py39h2bbff1b_1
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.8-py39h2bbff1b_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.4-py39h59b6b97_0
#   numpy              pkgs/main/win-64::numpy-1.26.4-py39h055cbcc_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.26.4-py39h65a83cf_0
#   opencv             pkgs/main/win-64::opencv-4.6.0-py39ha36de5b_5
#   pcre2              pkgs/main/win-64::pcre2-10.42-h0ff8eda_1
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-h879a1e9_9
#   qt-webengine       pkgs/main/win-64::qt-webengine-5.15.9-h5bd16bc_7
#   qtwebkit           pkgs/main/win-64::qtwebkit-5.212-h2bbfb41_5
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0
#   xz                 pkgs/main/win-64::xz-5.4.6-h8cc25b3_1
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_1
#   zstd               pkgs/main/win-64::zstd-1.5.5-hd43e919_2
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install matplotlib
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h2bbff1b_8          19 KB
#     brotli-bin-1.0.9           |       h2bbff1b_8          29 KB
#     contourpy-1.2.0            |   py39h59b6b97_0         202 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     fonttools-4.51.0           |   py39h2bbff1b_0         2.0 MB
#     importlib_resources-6.1.1  |   py39haa95532_1          55 KB
#     kiwisolver-1.4.4           |   py39hd77b12b_0          60 KB
#     libbrotlicommon-1.0.9      |       h2bbff1b_8          79 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_8          39 KB
#     libbrotlienc-1.0.9         |       h2bbff1b_8         261 KB
#     matplotlib-3.8.4           |   py39haa95532_0           9 KB
#     matplotlib-base-3.8.4      |   py39h4ed8f06_0         8.7 MB
#     ply-3.11                   |   py39haa95532_0          81 KB
#     pyparsing-3.0.9            |   py39haa95532_0         152 KB
#     pyqt-5.15.10               |   py39hd77b12b_0         4.1 MB
#     pyqt5-sip-12.13.0          |   py39h2bbff1b_0          75 KB
#     sip-6.7.12                 |   py39hd77b12b_0         517 KB
#     unicodedata2-15.1.0        |   py39h2bbff1b_0         525 KB
#     ------------------------------------------------------------
#                                            Total:        16.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_8
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_8
#   contourpy          pkgs/main/win-64::contourpy-1.2.0-py39h59b6b97_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/win-64::fonttools-4.51.0-py39h2bbff1b_0
#   importlib_resourc~ pkgs/main/win-64::importlib_resources-6.1.1-py39haa95532_1
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py39hd77b12b_0
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_8
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_8
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_8
#   matplotlib         pkgs/main/win-64::matplotlib-3.8.4-py39haa95532_0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.8.4-py39h4ed8f06_0
#   ply                pkgs/main/win-64::ply-3.11-py39haa95532_0
#   pyparsing          pkgs/main/win-64::pyparsing-3.0.9-py39haa95532_0
#   pyqt               pkgs/main/win-64::pyqt-5.15.10-py39hd77b12b_0
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.13.0-py39h2bbff1b_0
#   sip                pkgs/main/win-64::sip-6.7.12-py39hd77b12b_0
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py39h2bbff1b_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install cmake
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - cmake
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cmake-3.26.4               |       h693b641_0        12.0 MB
#     libuv-1.44.2               |       h2bbff1b_0         288 KB
#     ------------------------------------------------------------
#                                            Total:        12.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   cmake              pkgs/main/win-64::cmake-3.26.4-h693b641_0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge dlib
# Out:
# Channels:
# Note: you may need to restart the kernel to use updated packages.
#
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - dlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.3.1              |       h2466b09_1         8.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   dlib               conda-forge/win-64::dlib-19.24.0-py39hf203f3a_3
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#   ucrt               conda-forge/win-64::ucrt-10.0.22621.0-h57928b3_0
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.40.33810-ha82c5b3_20
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.3.11-~ --> conda-forge::ca-certificates-2024.6.2-h56e8100_0
#   openssl              pkgs/main::openssl-3.0.14-h827c3e9_0 --> conda-forge::openssl-3.3.1-h2466b09_1
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.29.30133~ --> conda-forge::vs2015_runtime-14.40.33810-h3bf8584_20
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/win-64::certifi-2024.6.2-py~ --> conda-forge/noarch::certifi-2024.6.2-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install pillow
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - pillow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     lcms2-2.12                 |       h83e58a3_0         454 KB
#     openjpeg-2.4.0             |       h4fc8c34_0         219 KB
#     pillow-10.3.0              |   py39h2bbff1b_0         846 KB
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.4.0-h4fc8c34_0
#   pillow             pkgs/main/win-64::pillow-10.3.0-py39h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2024.6.2-~ --> pkgs/main/win-64::certifi-2024.6.2-py39haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install face_recognition
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vinuka\anaconda3\envs\ipcv
#
#   added / updated specs:
#     - face_recognition
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     face_recognition-1.3.0     |     pyhd3deb0d_2          17 KB  conda-forge
#     face_recognition_models-0.3.0|     pyh9f0ad1d_0        87.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        87.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   click              pkgs/main/win-64::click-8.1.7-py39haa95532_0
#   face_recognition   conda-forge/noarch::face_recognition-1.3.0-pyhd3deb0d_2
#   face_recognition_~ conda-forge/noarch::face_recognition_models-0.3.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vinuka\anaconda3\envs\ipcv\lib\site-packages (from opencv-contrib-python) (1.26.4)
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0
1 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.9/45.5 MB 3.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 32.2/45.5 MB 3.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 32.3/45.5 MB 3.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 32.5/45.5 MB 3.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 32.7/45.5 MB 3.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 32.9/45.5 MB 3.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 32.9/45.5 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.0/45.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.4/45.5 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.6/45.5 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.8/45.5 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 34.0/45.5 MB 3.4 MB/s eta 0:00:04
#    ------------------------------ --------- 34.2/45.5 MB 3.4 MB/s eta 0:00:04
#    ------------------------------ --------- 34.3/45.5 MB 3.4 MB/s eta 0:00:04
#    ------------------------------ --------- 34.5/45.5 MB 3.4 MB/s eta 0:00:04
#    ------------------------------ --------- 34.6/45.5 MB 3.6 MB/s eta 0:00:04
#    ------------------------------ --------- 34.8/45.5 MB 3.5 MB/s eta 0:00:04
#    ------------------------------ --------- 35.0/45.5 MB 3.5 MB/s eta 0:00:04
#    ------------------------------ --------- 35.2/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 35.4/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 35.6/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 35.7/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 35.9/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 36.1/45.5 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 36.3/45.5 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 36.5/45.5 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 36.7/45.5 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 36.8/45.5 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 36.8/45.5 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 36.9/45.5 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 37.2/45.5 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 37.6/45.5 MB 3.7 MB/s eta 0:00:03
#    --------------------------------- ------ 37.8/45.5 MB 3.7 MB/s eta 0:00:03
#    --------------------------------- ------ 38.0/45.5 MB 3.8 MB/s eta 0:00:03
#    --------------------------------- ------ 38.1/45.5 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 38.3/45.5 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 38.5/45.5 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 38.7/45.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.9/45.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.1/45.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.3/45.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.5/45.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.7/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.9/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.1/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.3/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.4/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.5/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.5/45.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.5/45.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.5/45.5 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.6/45.5 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.6/45.5 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.6/45.5 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.7/45.5 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.7/45.5 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.7/45.5 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.7/45.5 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.8/45.5 MB 3.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 41.0/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.1/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.3/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.5/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.6/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.8/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 41.9/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 42.1/45.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------- -- 42.3/45.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 42.5/45.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 42.7/45.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 42.9/45.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 43.2/45.5 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/45.5 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/45.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.4/45.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.7/45.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/45.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.4/45.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  44.5/45.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  44.5/45.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  44.6/45.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  44.9/45.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 45.5/45.5 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv                 #Imports opencv-python
import numpy as np               #Imports numpy
import face_recognition          #Imports face_recognition library
import matplotlib.image as mpimg #Imports image module from matplotlib
import matplotlib.pyplot as plt  #Imports pyplot module from matplotlib

# %%
#Loads main image
main_img=mpimg.imread('./images/main_img.jpg')

# %%
#Displays main image
plt.imshow(main_img)

# %%
#Loads target image
target_img=mpimg.imread('./images/target_img.jpg')

# %%
#Displays target image
plt.imshow(target_img)

# %%
def compare_and_mark_faces(main_img_path, target_img_path):
    # load the main image and the target image from the disk
    main_img = face_recognition.load_image_file(main_img_path)
    target_img = face_recognition.load_image_file(target_img_path)

    # find face locations and face encodings for the main and target images
    main_face_locations = face_recognition.face_locations(main_img)
    target_face_locations = face_recognition.face_locations(target_img)
    
    main_face_encodings = face_recognition.face_encodings(main_img, main_face_locations)
    target_face_encodings = face_recognition.face_encodings(target_img, target_face_locations)

    # create a copy of the main image for visualization
    main_img_marked = np.copy(main_img)

    # iterate through faces in the main image
    for main_face_location, main_face_encoding in zip(main_face_locations, main_face_encodings):
        # compare the face encoding with all face encodings in the target image
        results = face_recognition.compare_faces(target_face_encodings, main_face_encoding)

        # check if there is at least one match
        if True in results:
            # find the index of the first matching face in the target image
            target_index = results.index(True)

            # draw a blue bounding box around the matching face in the main image
            top, right, bottom, left = main_face_location
            cv.rectangle(main_img_marked, (left, top), (right, bottom), (0, 0, 255), 2)

    # display the marked main image
    plt.imshow(main_img_marked)

# %%
main_img_path = "./images/main_img.jpg"
target_img_path = "./images/target_img.jpg"

# %%
compare_and_mark_faces(main_img_path,target_img_path)
